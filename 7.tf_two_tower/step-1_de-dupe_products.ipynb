# %% [markdown]
# # This notebook is a variant of load-features to de-duplicate the product info for candidate search
#
# ##### Description of the `.jsonl` file in `./training-data-schema.json`
#
# #### This does
#
# 1. Reads parameters for existing data
# 2. Create a small development data set
# 3. Expand to the full data and stream data into a formatted tfrecord in a new bucket `TF_RECORDS_DIR`

# %%
# !gsutil -m rm gs://prod-catalog-central/* #use this to clear the target directory - if you are adding additional fields
# Out:
# Removing gs://prod-catalog-central/file_00-0.tfrec...
# Removing gs://prod-catalog-central/file_01-1.tfrec...
# Removing gs://prod-catalog-central/file_02-1.tfrec...
# Removing gs://prod-catalog-central/file_03-1.tfrec...
# Removing gs://prod-catalog-central/file_04-1.tfrec...
# Removing gs://prod-catalog-central/file_05-1.tfrec...
# Removing gs://prod-catalog-central/file_06-1.tfrec...
# Removing gs://prod-catalog-central/file_07-1.tfrec...
# Removing gs://prod-catalog-central/file_104-1.tfrec...
# Removing gs://prod-catalog-central/file_10-1.tfrec...
# Removing gs://prod-catalog-central/file_08-1.tfrec...
# Removing gs://prod-catalog-central/file_09-1.tfrec...
# Removing gs://prod-catalog-central/file_103-1.tfrec...
# Removing gs://prod-catalog-central/file_100-1.tfrec...
# Removing gs://prod-catalog-central/file_101-1.tfrec...
# Removing gs://prod-catalog-central/file_102-1.tfrec...
# Removing gs://prod-catalog-central/file_105-1.tfrec...
# Removing gs://prod-catalog-central/file_106-1.tfrec...
# Removing gs://prod-catalog-central/file_107-1.tfrec...
# Removing gs://prod-catalog-central/file_109-1.tfrec...
# Removing gs://prod-catalog-central/file_108-1.tfrec...
# Removing gs://prod-catalog-central/file_11-1.tfrec...
# Removing gs://prod-catalog-central/file_110-1.tfrec...
# Removing gs://prod-catalog-central/file_111-1.tfrec...
# Removing gs://prod-catalog-central/file_112-1.tfrec...
# Removing gs://prod-catalog-central/file_113-1.tfrec...
# Removing gs://prod-catalog-central/file_114-1.tfrec...
# Removing gs://prod-catalog-central/file_116-1.tfrec...
# Removing gs://prod-catalog-central/file_115-1.tfrec...
# Removing gs://prod-catalog-central/file_117-1.tfrec...
# Removing gs://prod-catalog-central/file_118-1.tfrec...
# Removing gs://prod-catalog-central/file_119-1.tfrec...
# Removing gs://prod-catalog-central/file_12-1.tfrec...
# Removing gs://prod-catalog-central/file_120-1.tfrec...
# Removing gs://prod-catalog-central/file_121-1.tfrec...
# Removing gs://prod-catalog-central/file_122-1.tfrec...
# Removing gs://prod-catalog-central/file_123-1.tfrec...
# Removing gs://prod-catalog-central/file_126-1.tfrec...
# Removing gs://prod-catalog-central/file_124-1.tfrec...
# Removing gs://prod-catalog-central/file_127-1.tfrec...
# Removing gs://prod-catalog-central/file_125-1.tfrec...
# Removing gs://prod-catalog-central/file_129-1.tfrec...
# Removing gs://prod-catalog-central/file_128-1.tfrec...
# Removing gs://prod-catalog-central/file_13-1.tfrec...
# Removing gs://prod-catalog-central/file_130-1.tfrec...
# Removing gs://prod-catalog-central/file_131-1.tfrec...
# Removing gs://prod-catalog-central/file_135-1.tfrec...
# Removing gs://prod-catalog-central/file_132-1.tfrec...
# Removing gs://prod-catalog-central/file_133-1.tfrec...
# Removing gs://prod-catalog-central/file_134-1.tfrec...
# Removing gs://prod-catalog-central/file_136-1.tfrec...
# Removing gs://prod-catalog-central/file_138-1.tfrec...
# Removing gs://prod-catalog-central/file_137-1.tfrec...
# Removing gs://prod-catalog-central/file_141-1.tfrec...
# Removing gs://prod-catalog-central/file_139-1.tfrec...
# Removing gs://prod-catalog-central/file_142-1.tfrec...
# Removing gs://prod-catalog-central/file_14-1.tfrec...
# Removing gs://prod-catalog-central/file_140-1.tfrec...
# Removing gs://prod-catalog-central/file_143-1.tfrec...
# Removing gs://prod-catalog-central/file_144-1.tfrec...
# Removing gs://prod-catalog-central/file_145-1.tfrec...
# Removing gs://prod-catalog-central/file_146-1.tfrec...
# Removing gs://prod-catalog-central/file_148-1.tfrec...
# Removing gs://prod-catalog-central/file_147-1.tfrec...
# Removing gs://prod-catalog-central/file_149-1.tfrec...
# Removing gs://prod-catalog-central/file_15-1.tfrec...
# Removing gs://prod-catalog-central/file_153-1.tfrec...
# Removing gs://prod-catalog-central/file_151-1.tfrec...
# Removing gs://prod-catalog-central/file_150-1.tfrec...
# Removing gs://prod-catalog-central/file_155-1.tfrec...
# Removing gs://prod-catalog-central/file_154-1.tfrec...
# Removing gs://prod-catalog-central/file_152-1.tfrec...
# Removing gs://prod-catalog-central/file_156-1.tfrec...
# Removing gs://prod-catalog-central/file_157-1.tfrec...
# Removing gs://prod-catalog-central/file_158-1.tfrec...
# Removing gs://prod-catalog-central/file_160-1.tfrec...
# Removing gs://prod-catalog-central/file_16-1.tfrec...
# Removing gs://prod-catalog-central/file_161-1.tfrec...
# Removing gs://prod-catalog-central/file_159-1.tfrec...
# Removing gs://prod-catalog-central/file_162-1.tfrec...
# Removing gs://prod-catalog-central/file_163-1.tfrec...
# Removing gs://prod-catalog-central/file_164-1.tfrec...
# Removing gs://prod-catalog-central/file_165-1.tfrec...
# Removing gs://prod-catalog-central/file_167-1.tfrec...
# Removing gs://prod-catalog-central/file_168-1.tfrec...
# Removing gs://prod-catalog-central/file_169-1.tfrec...
# Removing gs://prod-catalog-central/file_166-1.tfrec...
# Removing gs://prod-catalog-central/file_171-1.tfrec...
# Removing gs://prod-catalog-central/file_17-1.tfrec...
# Removing gs://prod-catalog-central/file_170-1.tfrec...
# Removing gs://prod-catalog-central/file_172-1.tfrec...
# Removing gs://prod-catalog-central/file_173-1.tfrec...
# Removing gs://prod-catalog-central/file_179-1.tfrec...
# Removing gs://prod-catalog-central/file_174-1.tfrec...
# Removing gs://prod-catalog-central/file_177-1.tfrec...
# Removing gs://prod-catalog-central/file_18-1.tfrec...
# Removing gs://prod-catalog-central/file_180-1.tfrec...
# Removing gs://prod-catalog-central/file_175-1.tfrec...
# Removing gs://prod-catalog-central/file_176-1.tfrec...
# Removing gs://prod-catalog-central/file_178-1.tfrec...
# Removing gs://prod-catalog-central/file_181-1.tfrec...
# Removing gs://prod-catalog-central/file_182-1.tfrec...
# Removing gs://prod-catalog-central/file_183-1.tfrec...
# Removing gs://prod-catalog-central/file_186-1.tfrec...
# Removing gs://prod-catalog-central/file_184-1.tfrec...
# Removing gs://prod-catalog-central/file_187-1.tfrec...
# Removing gs://prod-catalog-central/file_185-1.tfrec...
# Removing gs://prod-catalog-central/file_188-1.tfrec...
# Removing gs://prod-catalog-central/file_189-1.tfrec...
# Removing gs://prod-catalog-central/file_19-1.tfrec...
# Removing gs://prod-catalog-central/file_190-1.tfrec...
# Removing gs://prod-catalog-central/file_191-1.tfrec...
# Removing gs://prod-catalog-central/file_193-1.tfrec...
# Removing gs://prod-catalog-central/file_192-1.tfrec...
# Removing gs://prod-catalog-central/file_194-1.tfrec...
# Removing gs://prod-catalog-central/file_195-1.tfrec...
# Removing gs://prod-catalog-central/file_196-1.tfrec...
# Removing gs://prod-catalog-central/file_197-1.tfrec...
# Removing gs://prod-catalog-central/file_198-1.tfrec...
# Removing gs://prod-catalog-central/file_199-1.tfrec...
# Removing gs://prod-catalog-central/file_20-1.tfrec...
# Removing gs://prod-catalog-central/file_200-1.tfrec...
# Removing gs://prod-catalog-central/file_201-1.tfrec...
# Removing gs://prod-catalog-central/file_202-1.tfrec...
# Removing gs://prod-catalog-central/file_203-1.tfrec...
# Removing gs://prod-catalog-central/file_205-1.tfrec...
# Removing gs://prod-catalog-central/file_204-1.tfrec...
# Removing gs://prod-catalog-central/file_206-1.tfrec...
# Removing gs://prod-catalog-central/file_208-1.tfrec...
# Removing gs://prod-catalog-central/file_207-1.tfrec...
# Removing gs://prod-catalog-central/file_209-1.tfrec...
# Removing gs://prod-catalog-central/file_210-1.tfrec...
# Removing gs://prod-catalog-central/file_211-1.tfrec...
# Removing gs://prod-catalog-central/file_215-1.tfrec...
# Removing gs://prod-catalog-central/file_212-1.tfrec...
# Removing gs://prod-catalog-central/file_213-1.tfrec...
# Removing gs://prod-catalog-central/file_21-1.tfrec...
# Removing gs://prod-catalog-central/file_218-1.tfrec...
# Removing gs://prod-catalog-central/file_214-1.tfrec...
# Removing gs://prod-catalog-central/file_216-1.tfrec...
# Removing gs://prod-catalog-central/file_220-1.tfrec...
# Removing gs://prod-catalog-central/file_217-1.tfrec...
# Removing gs://prod-catalog-central/file_22-1.tfrec...
# Removing gs://prod-catalog-central/file_219-1.tfrec...
# Removing gs://prod-catalog-central/file_221-1.tfrec...
# Removing gs://prod-catalog-central/file_222-1.tfrec...
# Removing gs://prod-catalog-central/file_223-1.tfrec...
# Removing gs://prod-catalog-central/file_224-1.tfrec...
# Removing gs://prod-catalog-central/file_225-1.tfrec...
# Removing gs://prod-catalog-central/file_229-1.tfrec...
# Removing gs://prod-catalog-central/file_23-1.tfrec...
# Removing gs://prod-catalog-central/file_226-1.tfrec...
# Removing gs://prod-catalog-central/file_227-1.tfrec...
# Removing gs://prod-catalog-central/file_228-1.tfrec...
# Removing gs://prod-catalog-central/file_232-1.tfrec...
# Removing gs://prod-catalog-central/file_230-1.tfrec...
# Removing gs://prod-catalog-central/file_231-1.tfrec...
# Removing gs://prod-catalog-central/file_234-1.tfrec...
# Removing gs://prod-catalog-central/file_235-1.tfrec...
# Removing gs://prod-catalog-central/file_233-1.tfrec...
# Removing gs://prod-catalog-central/file_236-1.tfrec...
# Removing gs://prod-catalog-central/file_24-1.tfrec...
# Removing gs://prod-catalog-central/file_241-1.tfrec...
# Removing gs://prod-catalog-central/file_240-1.tfrec...
# Removing gs://prod-catalog-central/file_239-1.tfrec...
# Removing gs://prod-catalog-central/file_238-1.tfrec...
# Removing gs://prod-catalog-central/file_237-1.tfrec...
# Removing gs://prod-catalog-central/file_243-1.tfrec...
# Removing gs://prod-catalog-central/file_242-1.tfrec...
# Removing gs://prod-catalog-central/file_244-1.tfrec...
# Removing gs://prod-catalog-central/file_245-1.tfrec...
# Removing gs://prod-catalog-central/file_246-1.tfrec...
# Removing gs://prod-catalog-central/file_248-1.tfrec...
# Removing gs://prod-catalog-central/file_249-1.tfrec...
# Removing gs://prod-catalog-central/file_251-1.tfrec...
# Removing gs://prod-catalog-central/file_247-1.tfrec...
# Removing gs://prod-catalog-central/file_253-1.tfrec...
# Removing gs://prod-catalog-central/file_25-1.tfrec...
# Removing gs://prod-catalog-central/file_254-1.tfrec...
# Removing gs://prod-catalog-central/file_252-1.tfrec...
# Removing gs://prod-catalog-central/file_255-1.tfrec...
# Removing gs://prod-catalog-central/file_250-1.tfrec...
# Removing gs://prod-catalog-central/file_257-1.tfrec...
# Removing gs://prod-catalog-central/file_256-1.tfrec...
# Removing gs://prod-catalog-central/file_258-1.tfrec...
# Removing gs://prod-catalog-central/file_259-1.tfrec...
# Removing gs://prod-catalog-central/file_261-1.tfrec...
# Removing gs://prod-catalog-central/file_260-1.tfrec...
# Removing gs://prod-catalog-central/file_26-1.tfrec...
# Removing gs://prod-catalog-central/file_262-1.tfrec...
# Removing gs://prod-catalog-central/file_264-1.tfrec...
# Removing gs://prod-catalog-central/file_265-1.tfrec...
# Removing gs://prod-catalog-central/file_263-1.tfrec...
# Removing gs://prod-catalog-central/file_266-1.tfrec...
# Removing gs://prod-catalog-central/file_267-1.tfrec...
# Removing gs://prod-catalog-central/file_268-1.tfrec...
# Removing gs://prod-catalog-central/file_269-1.tfrec...
# Removing gs://prod-catalog-central/file_27-1.tfrec...
# Removing gs://prod-catalog-central/file_271-1.tfrec...
# Removing gs://prod-catalog-central/file_270-1.tfrec...
# Removing gs://prod-catalog-central/file_272-1.tfrec...
# Removing gs://prod-catalog-central/file_273-1.tfrec...
# Removing gs://prod-catalog-central/file_274-1.tfrec...
# Removing gs://prod-catalog-central/file_275-1.tfrec...
# Removing gs://prod-catalog-central/file_276-1.tfrec...
# Removing gs://prod-catalog-central/file_277-1.tfrec...
# Removing gs://prod-catalog-central/file_278-1.tfrec...
# Removing gs://prod-catalog-central/file_279-1.tfrec...
# Removing gs://prod-catalog-central/file_283-1.tfrec...
# Removing gs://prod-catalog-central/file_280-1.tfrec...
# Removing gs://prod-catalog-central/file_28-1.tfrec...
# Removing gs://prod-catalog-central/file_286-1.tfrec...
# Removing gs://prod-catalog-central/file_281-1.tfrec...
# Removing gs://prod-catalog-central/file_287-1.tfrec...
# Removing gs://prod-catalog-central/file_284-1.tfrec...
# Removing gs://prod-catalog-central/file_285-1.tfrec...
# Removing gs://prod-catalog-central/file_282-1.tfrec...
# Removing gs://prod-catalog-central/file_288-1.tfrec...
# Removing gs://prod-catalog-central/file_290-1.tfrec...
# Removing gs://prod-catalog-central/file_289-1.tfrec...
# Removing gs://prod-catalog-central/file_29-1.tfrec...
# Removing gs://prod-catalog-central/file_291-1.tfrec...
# Removing gs://prod-catalog-central/file_293-1.tfrec...
# Removing gs://prod-catalog-central/file_295-1.tfrec...
# Removing gs://prod-catalog-central/file_294-1.tfrec...
# Removing gs://prod-catalog-central/file_292-1.tfrec...
# Removing gs://prod-catalog-central/file_296-1.tfrec...
# Removing gs://prod-catalog-central/file_298-1.tfrec...
# Removing gs://prod-catalog-central/file_297-1.tfrec...
# Removing gs://prod-catalog-central/file_299-1.tfrec...
# Removing gs://prod-catalog-central/file_30-1.tfrec...
# Removing gs://prod-catalog-central/file_300-1.tfrec...
# Removing gs://prod-catalog-central/file_301-1.tfrec...
# Removing gs://prod-catalog-central/file_302-1.tfrec...
# Removing gs://prod-catalog-central/file_303-1.tfrec...
# Removing gs://prod-catalog-central/file_308-1.tfrec...
# Removing gs://prod-catalog-central/file_307-1.tfrec...
# Removing gs://prod-catalog-central/file_309-1.tfrec...
# Removing gs://prod-catalog-central/file_304-1.tfrec...
# Removing gs://prod-catalog-central/file_305-1.tfrec...
# Removing gs://prod-catalog-central/file_306-1.tfrec...
# Removing gs://prod-catalog-central/file_311-1.tfrec...
# Removing gs://prod-catalog-central/file_310-1.tfrec...
# Removing gs://prod-catalog-central/file_312-1.tfrec...
# Removing gs://prod-catalog-central/file_31-1.tfrec...
# Removing gs://prod-catalog-central/file_313-1.tfrec...
# Removing gs://prod-catalog-central/file_314-1.tfrec...
# Removing gs://prod-catalog-central/file_315-1.tfrec...
# Removing gs://prod-catalog-central/file_316-1.tfrec...
# Removing gs://prod-catalog-central/file_317-1.tfrec...
# Removing gs://prod-catalog-central/file_32-1.tfrec...
# Removing gs://prod-catalog-central/file_318-1.tfrec...
# Removing gs://prod-catalog-central/file_320-1.tfrec...
# Removing gs://prod-catalog-central/file_319-1.tfrec...
# Removing gs://prod-catalog-central/file_321-1.tfrec...
# Removing gs://prod-catalog-central/file_322-1.tfrec...
# Removing gs://prod-catalog-central/file_323-1.tfrec...
# Removing gs://prod-catalog-central/file_324-1.tfrec...
# Removing gs://prod-catalog-central/file_325-1.tfrec...
# Removing gs://prod-catalog-central/file_326-1.tfrec...
# Removing gs://prod-catalog-central/file_327-1.tfrec...
# Removing gs://prod-catalog-central/file_328-1.tfrec...
# Removing gs://prod-catalog-central/file_331-1.tfrec...
# Removing gs://prod-catalog-central/file_329-1.tfrec...
# Removing gs://prod-catalog-central/file_332-1.tfrec...
# Removing gs://prod-catalog-central/file_33-1.tfrec...
# Removing gs://prod-catalog-central/file_330-1.tfrec...
# Removing gs://prod-catalog-central/file_333-1.tfrec...
# Removing gs://prod-catalog-central/file_334-1.tfrec...
# Removing gs://prod-catalog-central/file_337-1.tfrec...
# Removing gs://prod-catalog-central/file_335-1.tfrec...
# Removing gs://prod-catalog-central/file_338-1.tfrec...
# Removing gs://prod-catalog-central/file_34-1.tfrec...
# Removing gs://prod-catalog-central/file_336-1.tfrec...
# Removing gs://prod-catalog-central/file_339-1.tfrec...
# Removing gs://prod-catalog-central/file_340-1.tfrec...
# Removing gs://prod-catalog-central/file_341-1.tfrec...
# Removing gs://prod-catalog-central/file_342-1.tfrec...
# Removing gs://prod-catalog-central/file_343-1.tfrec...
# Removing gs://prod-catalog-central/file_344-1.tfrec...
# Removing gs://prod-catalog-central/file_345-1.tfrec...
# Removing gs://prod-catalog-central/file_346-1.tfrec...
# Removing gs://prod-catalog-central/file_347-1.tfrec...
# Removing gs://prod-catalog-central/file_35-1.tfrec...
# Removing gs://prod-catalog-central/file_350-1.tfrec...
# Removing gs://prod-catalog-central/file_351-1.tfrec...
# Removing gs://prod-catalog-central/file_352-1.tfrec...
# Removing gs://prod-catalog-central/file_348-1.tfrec...
# Removing gs://prod-catalog-central/file_349-1.tfrec...
# Removing gs://prod-catalog-central/file_354-1.tfrec...
# Removing gs://prod-catalog-central/file_353-1.tfrec...
# Removing gs://prod-catalog-central/file_357-1.tfrec...
# Removing gs://prod-catalog-central/file_355-1.tfrec...
# Removing gs://prod-catalog-central/file_356-1.tfrec...
# Removing gs://prod-catalog-central/file_359-1.tfrec...
# Removing gs://prod-catalog-central/file_358-1.tfrec...
# Removing gs://prod-catalog-central/file_361-1.tfrec...
# Removing gs://prod-catalog-central/file_363-1.tfrec...
# Removing gs://prod-catalog-central/file_36-1.tfrec...
# Removing gs://prod-catalog-central/file_360-1.tfrec...
# Removing gs://prod-catalog-central/file_362-1.tfrec...
# Removing gs://prod-catalog-central/file_364-1.tfrec...
# Removing gs://prod-catalog-central/file_365-1.tfrec...
# Removing gs://prod-catalog-central/file_366-1.tfrec...
# Removing gs://prod-catalog-central/file_367-1.tfrec...
# Removing gs://prod-catalog-central/file_369-1.tfrec...
# Removing gs://prod-catalog-central/file_368-1.tfrec...
# Removing gs://prod-catalog-central/file_37-1.tfrec...
# Removing gs://prod-catalog-central/file_370-1.tfrec...
# Removing gs://prod-catalog-central/file_371-1.tfrec...
# Removing gs://prod-catalog-central/file_372-1.tfrec...
# Removing gs://prod-catalog-central/file_373-1.tfrec...
# Removing gs://prod-catalog-central/file_374-1.tfrec...
# Removing gs://prod-catalog-central/file_375-1.tfrec...
# Removing gs://prod-catalog-central/file_376-1.tfrec...
# Removing gs://prod-catalog-central/file_377-1.tfrec...
# Removing gs://prod-catalog-central/file_378-1.tfrec...
# Removing gs://prod-catalog-central/file_379-1.tfrec...
# Removing gs://prod-catalog-central/file_381-1.tfrec...
# Removing gs://prod-catalog-central/file_38-1.tfrec...
# Removing gs://prod-catalog-central/file_382-1.tfrec...
# Removing gs://prod-catalog-central/file_380-1.tfrec...
# Removing gs://prod-catalog-central/file_383-1.tfrec...
# Removing gs://prod-catalog-central/file_384-1.tfrec...
# Removing gs://prod-catalog-central/file_385-1.tfrec...
# Removing gs://prod-catalog-central/file_386-1.tfrec...
# Removing gs://prod-catalog-central/file_387-1.tfrec...
# Removing gs://prod-catalog-central/file_388-1.tfrec...
# Removing gs://prod-catalog-central/file_391-1.tfrec...
# Removing gs://prod-catalog-central/file_389-1.tfrec...
# Removing gs://prod-catalog-central/file_390-1.tfrec...
# Removing gs://prod-catalog-central/file_39-1.tfrec...
# Removing gs://prod-catalog-central/file_392-1.tfrec...
# Removing gs://prod-catalog-central/file_393-1.tfrec...
# Removing gs://prod-catalog-central/file_394-1.tfrec...
# Removing gs://prod-catalog-central/file_395-1.tfrec...
# Removing gs://prod-catalog-central/file_397-1.tfrec...
# Removing gs://prod-catalog-central/file_396-1.tfrec...
# Removing gs://prod-catalog-central/file_398-1.tfrec...
# Removing gs://prod-catalog-central/file_399-1.tfrec...
# Removing gs://prod-catalog-central/file_40-1.tfrec...
# Removing gs://prod-catalog-central/file_400-1.tfrec...
# Removing gs://prod-catalog-central/file_401-1.tfrec...
# Removing gs://prod-catalog-central/file_403-1.tfrec...
# Removing gs://prod-catalog-central/file_402-1.tfrec...
# Removing gs://prod-catalog-central/file_404-1.tfrec...
# Removing gs://prod-catalog-central/file_406-1.tfrec...
# Removing gs://prod-catalog-central/file_405-1.tfrec...
# Removing gs://prod-catalog-central/file_409-1.tfrec...
# Removing gs://prod-catalog-central/file_41-1.tfrec...
# Removing gs://prod-catalog-central/file_407-1.tfrec...
# Removing gs://prod-catalog-central/file_410-1.tfrec...
# Removing gs://prod-catalog-central/file_408-1.tfrec...
# Removing gs://prod-catalog-central/file_411-1.tfrec...
# Removing gs://prod-catalog-central/file_412-1.tfrec...
# Removing gs://prod-catalog-central/file_413-1.tfrec...
# Removing gs://prod-catalog-central/file_415-1.tfrec...
# Removing gs://prod-catalog-central/file_418-1.tfrec...
# Removing gs://prod-catalog-central/file_414-1.tfrec...
# Removing gs://prod-catalog-central/file_416-1.tfrec...
# Removing gs://prod-catalog-central/file_417-1.tfrec...
# Removing gs://prod-catalog-central/file_419-1.tfrec...
# Removing gs://prod-catalog-central/file_42-1.tfrec...
# Removing gs://prod-catalog-central/file_420-1.tfrec...
# Removing gs://prod-catalog-central/file_421-1.tfrec...
# Removing gs://prod-catalog-central/file_423-1.tfrec...
# Removing gs://prod-catalog-central/file_422-1.tfrec...
# Removing gs://prod-catalog-central/file_424-1.tfrec...
# Removing gs://prod-catalog-central/file_425-1.tfrec...
# Removing gs://prod-catalog-central/file_427-1.tfrec...
# Removing gs://prod-catalog-central/file_426-1.tfrec...
# Removing gs://prod-catalog-central/file_428-1.tfrec...
# Removing gs://prod-catalog-central/file_433-1.tfrec...
# Removing gs://prod-catalog-central/file_429-1.tfrec...
# Removing gs://prod-catalog-central/file_43-1.tfrec...
# Removing gs://prod-catalog-central/file_430-1.tfrec...
# Removing gs://prod-catalog-central/file_431-1.tfrec...
# Removing gs://prod-catalog-central/file_434-1.tfrec...
# Removing gs://prod-catalog-central/file_437-1.tfrec...
# Removing gs://prod-catalog-central/file_436-1.tfrec...
# Removing gs://prod-catalog-central/file_432-1.tfrec...
# Removing gs://prod-catalog-central/file_435-1.tfrec...
# Removing gs://prod-catalog-central/file_438-1.tfrec...
# Removing gs://prod-catalog-central/file_439-1.tfrec...
# Removing gs://prod-catalog-central/file_440-1.tfrec...
# Removing gs://prod-catalog-central/file_44-1.tfrec...
# Removing gs://prod-catalog-central/file_442-1.tfrec...
# Removing gs://prod-catalog-central/file_443-1.tfrec...
# Removing gs://prod-catalog-central/file_441-1.tfrec...
# Removing gs://prod-catalog-central/file_444-1.tfrec...
# Removing gs://prod-catalog-central/file_445-1.tfrec...
# Removing gs://prod-catalog-central/file_446-1.tfrec...
# Removing gs://prod-catalog-central/file_447-1.tfrec...
# Removing gs://prod-catalog-central/file_449-1.tfrec...
# Removing gs://prod-catalog-central/file_45-1.tfrec...
# Removing gs://prod-catalog-central/file_448-1.tfrec...
# Removing gs://prod-catalog-central/file_450-1.tfrec...
# Removing gs://prod-catalog-central/file_452-1.tfrec...
# Removing gs://prod-catalog-central/file_453-1.tfrec...
# Removing gs://prod-catalog-central/file_451-1.tfrec...
# Removing gs://prod-catalog-central/file_454-1.tfrec...
# Removing gs://prod-catalog-central/file_455-1.tfrec...
# Removing gs://prod-catalog-central/file_456-1.tfrec...
# Removing gs://prod-catalog-central/file_50-1.tfrec...
# Removing gs://prod-catalog-central/file_457-1.tfrec...
# Removing gs://prod-catalog-central/file_48-1.tfrec...
# Removing gs://prod-catalog-central/file_51-1.tfrec...
# Removing gs://prod-catalog-central/file_49-1.tfrec...
# Removing gs://prod-catalog-central/file_46-1.tfrec...
# Removing gs://prod-catalog-central/file_47-1.tfrec...
# Removing gs://prod-catalog-central/file_53-1.tfrec...
# Removing gs://prod-catalog-central/file_52-1.tfrec...
# Removing gs://prod-catalog-central/file_54-1.tfrec...
# Removing gs://prod-catalog-central/file_55-1.tfrec...
# Removing gs://prod-catalog-central/file_56-1.tfrec...
# Removing gs://prod-catalog-central/file_57-1.tfrec...
# Removing gs://prod-catalog-central/file_58-1.tfrec...
# Removing gs://prod-catalog-central/file_59-1.tfrec...
# Removing gs://prod-catalog-central/file_60-1.tfrec...
# Removing gs://prod-catalog-central/file_62-1.tfrec...
# Removing gs://prod-catalog-central/file_61-1.tfrec...
# Removing gs://prod-catalog-central/file_67-1.tfrec...
# Removing gs://prod-catalog-central/file_63-1.tfrec...
# Removing gs://prod-catalog-central/file_64-1.tfrec...
# Removing gs://prod-catalog-central/file_65-1.tfrec...
# Removing gs://prod-catalog-central/file_68-1.tfrec...
# Removing gs://prod-catalog-central/file_66-1.tfrec...
# Removing gs://prod-catalog-central/file_74-1.tfrec...
# Removing gs://prod-catalog-central/file_69-1.tfrec...
# Removing gs://prod-catalog-central/file_70-1.tfrec...
# Removing gs://prod-catalog-central/file_75-1.tfrec...
# Removing gs://prod-catalog-central/file_71-1.tfrec...
# Removing gs://prod-catalog-central/file_76-1.tfrec...
# Removing gs://prod-catalog-central/file_72-1.tfrec...
# Removing gs://prod-catalog-central/file_73-1.tfrec...
# Removing gs://prod-catalog-central/file_78-1.tfrec...
# Removing gs://prod-catalog-central/file_77-1.tfrec...
# Removing gs://prod-catalog-central/file_79-1.tfrec...
# Removing gs://prod-catalog-central/file_80-1.tfrec...
# Removing gs://prod-catalog-central/file_81-1.tfrec...
# Removing gs://prod-catalog-central/file_82-1.tfrec...
# Removing gs://prod-catalog-central/file_84-1.tfrec...
# Removing gs://prod-catalog-central/file_83-1.tfrec...
# Removing gs://prod-catalog-central/file_85-1.tfrec...
# Removing gs://prod-catalog-central/file_86-1.tfrec...
# Removing gs://prod-catalog-central/file_87-1.tfrec...
# Removing gs://prod-catalog-central/file_88-1.tfrec...
# Removing gs://prod-catalog-central/file_91-1.tfrec...
# Removing gs://prod-catalog-central/file_89-1.tfrec...
# Removing gs://prod-catalog-central/file_92-1.tfrec...
# Removing gs://prod-catalog-central/file_90-1.tfrec...
# Removing gs://prod-catalog-central/file_95-1.tfrec...
# Removing gs://prod-catalog-central/file_96-1.tfrec...
# Removing gs://prod-catalog-central/file_97-1.tfrec...
# Removing gs://prod-catalog-central/file_93-1.tfrec...
# Removing gs://prod-catalog-central/file_94-1.tfrec...
# Removing gs://prod-catalog-central/file_98-1.tfrec...
# Removing gs://prod-catalog-central/file_99-1.tfrec...
# / [458/458 objects] 100% Done
# Operation completed over 458 objects.

# %%
#set parameters
BUCKET = 'gs://mcskinner-sample-data/2tower/last-view'
SCHEMA_JSON = 'gs://mcskinner-sample-data/2tower/last-view/training-data-schema.json'
TRAIN_JSON = 'gs://tfrs-sample-data/training-data.jsonl'
MY_BUCKET = 'gs://tfrs-sample-data'
TF_RECORDS_DIR = 'gs://prod-catalog-central'
SMALL_DATASET = 'gs://tfrs-sample-data/training-data_dev.jsonl'

# %%
### Create a smaller dev dataset first
import json
import os
import subprocess
from tensorflow.python.lib.io import file_io


ROW_LIMIT = 10000
jsonl_path = os.path.join(MY_BUCKET, 'training-data.jsonl')
SMALL_DATASET = 'gs://tfrs-sample-data/training-data_dev.jsonl'

input_file_columns = subprocess.getoutput(f'gsutil cp {jsonl_path} - | head -{ROW_LIMIT} | gsutil cp - {SMALL_DATASET}')

# %% [markdown]
# ### Read in the schema for later parsing

# %% [markdown]
# #### FYI:Pre-calculated counts

# %%
num_records = 4293302 #sum(1 for _ in file_io.FileIO(SMALL_DATASET, 'rb')) #CHANGE THIS TO LARGE DATASET WHEN READY
print("Total number of records: {}".format(num_records))
# Out:
# Total number of records: 4293302

# %% [markdown]
# ### Establish the parameters
#
# `num_samples` is the number of data samples for each TFRECORD file
#
# `num_tfrecods` is total number of TFRecords that we will create.
#
# Generally - aim for around 100 MB size tfrecord files

# %%
#To be tuned later

num_samples = 12228 * 3 #did 3x b/c it was coming out about 33 MB per shard with original number
num_tfrecords = num_records // num_samples 
if num_records % num_samples:
    num_tfrecords += 1

print("Number of Expected TFRecords: {}".format(num_tfrecords))
# Out:
# Number of Expected TFRecords: 118

# %% [markdown]
# ### These helper functions declare different feature types
# This is used to parase the jsonl file
#
# Note [this](https://keras.io/examples/keras_recipes/creating_tfrecords/#define-dataset-helper-functions) is a good resource
#
# #### Notes on data transforms:
# * Grabbing all fields avaialble for query
# * Transforming and flattening of array / ragged data inputs (`['last_viewed', 'ss_prodTypeCombo_ss',` etc..`]`)
# * Using special delimiter (`|` in this case) to later unpack values as a string-split for text vectorizor layer

# %%
import tensorflow as tf
import numpy as np


def string_array(value):
    """Returns a bytes_list from a string / byte."""
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[v.encode('utf-8') for v in value]))


def float_feature(value):
    """Returns a float_list from a float / double."""
    return tf.train.Feature(float_list=tf.train.FloatList(value=[float(v) for v in value]))


def int64_feature(value):
    """Returns an int64_list from a bool / enum / int / uint."""
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[int(v) for v in value]))


def float_feature_list(value):
    """Returns a list of float_list from a float / double."""
    return tf.train.Feature(float_list=tf.train.FloatList(value=value))

    
def parse_line_de_dupe(ln):
    
    c_ln = ln['candidate']
    
    pt = ""
    for item in c_ln['productTypeCombo_ss']:
        pt = pt + "|" + item

    pt_feature = tf.train.Feature(bytes_list=tf.train.BytesList(value=[str(pt).encode('utf-8')]))

    feature = {
        #########COMMENT OUT QUERY FEATURES - THIS IS GOING TO BE A DE-DUPLICATED TF-REC
        #candidate features
        "IVM_s": string_array(c_ln['IVM_s']), 
        "description": string_array(c_ln['description']),
        "price_td": float_feature(c_ln['price_td']),
        "PriceRange_s": string_array(c_ln['PriceRange_s']),
        "productTypeCombo_ss": pt_feature, 
        "visual": float_feature(c_ln['visual'])
    }
    return tf.train.Example(features=tf.train.Features(feature=feature))

# %% [markdown]
# ### Create a target TF Records dataset for later use

# %%
import time
from tqdm import tqdm

# this will generate data into the correct format for tf_records
record_counter = 0
lns = [] #empty holder for the lines
tfrec_counter = 0
sku_accum = [] # this will hold a running list of SKU_s (in memory to de-dupe) 
#MAKE SURE YOU HAVE ENOUGH MACHINE MEMORY TO HOLD A LIST OF IVM_S (uniques) from the data

# quick function to write the data as we read through it
def write_a_tfrec(lns):
    #next write to a tfrecord
    with tf.io.TFRecordWriter(
        TF_RECORDS_DIR + "/file_%.2i-%i.tfrec" % (tfrec_counter, len(lns))
    ) as writer:
        for ln in lns:
            c_ln = ln['candidate']
            if c_ln['IVM_s'] in sku_accum:
                pass
            else:
                sku_accum.append(c_ln['IVM_s'])
                example  = parse_line_de_dupe(ln)
                writer.write(example.SerializeToString())
            

###### This still needs work as data will not be evenly distributed - it will get smaller as shard sequence increases (harder to find unique products as you go)
with file_io.FileIO(TRAIN_JSON, 'r') as reader:
    for line in reader:
        record_counter += 1
        if record_counter % num_samples == 0 or record_counter == num_records: 
            write_a_tfrec(lns) #write out a batch
            lns = [] #reset to a new batch
            tfrec_counter += 1
#             pbar.update(record_counter)
        else:
            pass
#         lns.append(json.loads(line)) #toggle if you want to save stuff locally
