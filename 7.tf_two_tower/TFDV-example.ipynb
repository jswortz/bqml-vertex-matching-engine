# %%
# !pip install tensorflow-data-validation==1.1.1 --user

# %%
import tensorflow_data_validation as tfdv

TF_RECORDS_DIR = 'gs://tfrs-tf-records/file_00-12227.tfrec'


stats = tfdv.generate_statistics_from_tfrecord(data_location=TF_RECORDS_DIR)
tfdv.visualize_statistics(stats)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 12
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_util.py:247: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.7/site-packages/tensorflow_data_validation/utils/stats_util.py:247: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
# ...
